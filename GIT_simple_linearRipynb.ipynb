# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# On the left we have our dependent variable which we try to predict. on the right we have our independent variable which is the predictor. here we have b0 which is the y-intercept also known as (constant) and b1 is the slope coefficient

# %% [markdown]
# **Importing the libraries**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/experience_salaries.csv")
df.head(10)
# Out:
#    YearsExperience  Salary
# 0                7   55731
# 1               20  113154
# 2               15   94762
# 3               11   74056
# 4                8   65110
# 5                7   56840
# 6               19  102028
# 7               11   76385
# 8               11   69502
# 9                4   47910

# %% [markdown]
# What is CSV?
#
# Comma seperated values.

# %% [markdown]
# **Linear Regression** is building a model that can estimate a linear relationship between one or more independent variables.
#
# **Note:** We can have more features like age.
#
# To train this model, we need to split the dataset into:
# - **Training set** = 80
# - **Testing set** = 20
#
# The **Training Set** is the data that we provide when training the model, while the **Test Set** is used to evaluate the accuracy of the model after training.
#
# The reason we have to split the dataset into training and test sets is that if we test the model on the same data it was trained on, we wouldn’t get a realistic picture of how well the model performs on unseen data. The whole idea is to input years of experience and get the predicted salaries.
#
# The most common way to split the data is **80/20**—80% for training and 20% for testing. This ratio can vary depending on the size of the dataset.
#
# When the model is well-trained, you should have:
# - **m = 9332.9** (Slope, θ1)
# - **b = 25609.9** (Y-intercept)

# %%
df.tail()
# Out:
#     YearsExperience  Salary
# 95               12   73197
# 96                2   40125
# 97                1   30930
# 98               16   95287
# 99                5   53800

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count       100.000000     100.000000
# mean         10.010000   70149.110000
# std           5.535003   22030.768037
# min           1.000000   29202.000000
# 25%           5.750000   54050.500000
# 50%           9.500000   67653.500000
# 75%          15.000000   89860.750000
# max          20.000000  113154.000000

# %%
print(df.shape)
# Out:
# (100, 2)

# %% [markdown]
# **Data Visualization**
#
# *importing the library*

# %%
import matplotlib.pyplot as plt

plt.scatter(df['YearsExperience'], df['Salary'], color = 'red')
plt.title("Years of Experience vs Salary")  # Add title
plt.xlabel("Years of Experience")  # Label for x-axis
plt.ylabel("Salary (USD)")  # Label for y-axis
plt.show()

# %% [markdown]
# **Machine learning.**
# slipting the dataset

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]              #dependent variable
#it is in lower case because it going to be our vector not a two dimension

# %%
X.head()
# Out:
#    YearsExperience
# 0                7
# 1               20
# 2               15
# 3               11
# 4                8

# %%
y.head()
# Out:
# 0     55731
# 1    113154
# 2     94762
# 3     74056
# 4     65110
# Name: Salary, dtype: int64

# %% [markdown]
# We want the output to be in a **matrix format** as a **two-dimensional NumPy array**.
#
# The **`y`** variable appears in its current form because it is displayed as a **vector**, which is the standard way to represent a single-column dataset in NumPy.

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
print(X)
print(y)
# Out:
# [[ 7]
#  [20]
#  [15]
#  [11]
#  [ 8]
#  [ 7]
#  [19]
#  [11]
#  [11]
#  [ 4]
#  [ 8]
#  [ 3]
#  [ 2]
#  [12]
#  [ 6]
#  [ 2]
#  [ 1]
#  [12]
#  [12]
#  [17]
#  [10]
#  [16]
#  [15]
#  [15]
#  [19]
#  [12]
#  [20]
#  [ 3]
#  [ 5]
#  [19]
#  [ 7]
#  [ 9]
#  [ 7]
#  [18]
#  [ 4]
#  [14]
#  [18]
#  [ 9]
#  [ 2]
#  [20]
#  [15]
#  [ 7]
#  [12]
#  [ 8]
#  [15]
#  [ 3]
#  [14]
#  [17]
#  [ 4]
#  [18]
#  [ 8]
#  [ 4]
#  [ 2]
#  [ 6]
#  [10]
#  [ 4]
#  [18]
#  [12]
#  [ 2]
#  [10]
#  [ 4]
#  [14]
#  [16]
#  [15]
#  [ 8]
#  [14]
#  [ 8]
#  [16]
#  [13]
#  [18]
#  [15]
#  [13]
#  [ 9]
#  [15]
#  [13]
#  [ 1]
#  [ 7]
#  [ 9]
#  [ 1]
#  [12]
#  [ 8]
#  [11]
#  [19]
#  [17]
#  [ 8]
#  [ 3]
#  [ 3]
#  [ 1]
#  [ 5]
#  [10]
#  [ 7]
#  [ 9]
#  [ 7]
#  [ 9]
#  [ 8]
#  [12]
#  [ 2]
#  [ 1]
#  [16]
#  [ 5]]
# [ 55731 113154  94762  74056  65110  56840 102028  76385  69502  47910
#   66062  43938  37488  73206  54134  38977  36721  80035  74484 100858
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
print(X_train.shape) #this is a numpy array that features of 80 rows and 1 columns.
print(X_test.shape) #this is a matrix with two dimentional
print(y_train.shape) #this is a vector
print(y_test.shape) #this is a vector
# Out:
# (80, 1)
# (20, 1)
# (80,)
# (20,)

# %%
from sklearn.linear_model import LinearRegression
#create the model
model = LinearRegression()

#train the model using the traning set
model.fit(X_train, y_train) #behind the scrence this is training your model i.e finding the slop for the feature/object
# Out:
# LinearRegression()

# %%
#get the model predict on the test set
y_pred = model.predict(X_test)
print(y_pred)
print(y_test)
# Out:
# [ 62049.83379934  62049.83379934 101798.81869214  73974.52926718
#   66024.73228862  77949.42775646 101798.81869214 105773.71718142
#  101798.81869214  85899.22473502  58074.93531006 109748.6156707
#  101798.81869214  38200.44286366  46150.23984222  58074.93531006
#   66024.73228862  89874.1232243   34225.54437438  62049.83379934]
# [ 62172  62535  98059  70707  63931  80035 100157 106791 104280  87585
#   61004 107693 100748  41901  48526  57636  64242  94721  35528  66062]

# %% [markdown]
# ##This really didn't do well but lets try to visualize our data on the train set

# %%
#visualizing the training set with the predictions
plt.scatter(X_train, y_train, color = 'pink')
plt.plot(X_train, model.predict(X_train), color ="red")
plt.title("Salary vs Years of Experience (Training set)")  #title
plt.xlabel("Years of Experience")  # Label for x-axis
plt.ylabel("Salary (USD)")  # Label for y-axis
plt.show()

# %%
#The pink datapoint is the actual true values that our dataset has for the traning set
#The red line represent our model prediction

# %%
#visualizing the test set with the predictions
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_test, model.predict(X_test), color ="blue")
plt.title("Salary vs Years of Experience (Test set)")  #title
plt.xlabel("Years of Experience")  # Label for x-axis
plt.ylabel("Salary (USD)")  # Label for y-axis
plt.show()

# %% [markdown]
# # Let's not rely solely on the graph for predictions; instead, let's consider other metrics as well.

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# In linear regression, these two metrics help evaluate how well the model predicts the data:
#
# 1. **Mean Squared Error (MSE)**:
#    - Measures how far the predicted values are from the actual values.
#    - It calculates the average of the squared differences between actual and predicted values.
#    - A lower MSE means the model's predictions are more accurate.
#
# 2. **R² Score (R-squared)**:
#    - Shows how well the model explains the variation in the data.
#    - It ranges from 0 to 1, where 1 means perfect prediction and 0 means the model doesn't explain the data at all.
#    - Higher R² means a better fit.
#
# In short:
# - **MSE tells you how wrong your predictions are.**
# - **R² tells you how well your model fits the data.**

# %%
#What is error? This is the difference between the actual values and the predicted values
#i.e the difference between the y_test and y_pred.
print("Mean Squared error: ", mean_squared_error(y_test, y_pred))
print("R2 Score: ", r2_score(y_test, y_pred)) #this need to be close to one as possible.
#remember we have a small dataset with 80 point
# Out:
# Mean Squared error:  6213979.851598765
# R2 Score:  0.9873637169634025

# %%
print('Slop: ', model.coef_)
print('Intercept: ', model.intercept_)

#this is our model. we can take the slop and intercept to create a simple line using X is equal MX plus b.
#with that we can get the best fit line for the data
# Out:
# Slop:  [3974.89848928]
# Intercept:  30250.64588509941

# %%
#let's predict someone with 4years experience
years_of_experience = 4
salary = model.predict([[years_of_experience]])
print("Salary for someone with 4 years experience: ", salary)
# Out:
# Salary for someone with 4 years experience:  [46150.23984222]
